# %%
% cd ./drive/MyDrive/BU_CS585
# Out:
# /content/drive/MyDrive/BU_CS585

# %%
! git clone https://github.com/GiorgosKarantonis/PuppetGAN.git
# Out:
# Cloning into 'PuppetGAN'...
# remote: Enumerating objects: 10262, done.
# remote: Counting objects: 100% (68/68), done.
# remote: Compressing objects: 100% (61/61), done.
# remote: Total 10262 (delta 38), reused 16 (delta 7), pack-reused 10194
# Receiving objects: 100% (10262/10262), 22.86 MiB | 8.00 MiB/s, done.
# Resolving deltas: 100% (242/242), done.

# %%
% cd ./PuppetGAN
# Out:
# /content/drive/MyDrive/BU_CS585/PuppetGAN

# %%
! pip install -r requirements.txt
# Out:
# Collecting absl-py==0.10.0
#   Downloading https://files.pythonhosted.org/packages/b9/07/f69dd3367368ad69f174bfe426a973651412ec11d48ec05c000f19fe0561/absl_py-0.10.0-py3-none-any.whl (127kB)
#      |████████████████████████████████| 133kB 7.5MB/s
# Requirement already satisfied: astor==0.8.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 2)) (0.8.1)
# Collecting cachetools==4.1.1
#   Downloading https://files.pythonhosted.org/packages/cd/5c/f3aa86b6d5482f3051b433c7616668a9b96fbe49a622210e2c9781938a5c/cachetools-4.1.1-py3-none-any.whl
# Collecting certifi==2020.6.20
#   Downloading https://files.pythonhosted.org/packages/5e/c4/6c4fe722df5343c33226f0b4e0bb042e4dc13483228b4718baf286f86d87/certifi-2020.6.20-py2.py3-none-any.whl (156kB)
#      |████████████████████████████████| 163kB 8.2MB/s
# Requirement already satisfied: chardet==3.0.4 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 5)) (3.0.4)
# Requirement already satisfied: click==7.1.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 6)) (7.1.2)
# Requirement already satisfied: cycler==0.10.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 7)) (0.10.0)
# Collecting gast==0.2.2
#   Downloading https://files.pythonhosted.org/packages/4e/35/11749bf99b2d4e3cceb4d55ca22590b0d7c2c62b9de38ac4a4a7f4687421/gast-0.2.2.tar.gz
# Collecting google-auth==1.21.3
#   Downloading https://files.pythonhosted.org/packages/68/7f/dc8d3cf77062da8c76ebfb63ad66311463048fddf16ca8c81043a7fc94de/google_auth-1.21.3-py2.py3-none-any.whl (93kB)
#      |████████████████████████████████| 102kB 7.7MB/s
# Collecting google-auth-oauthlib==0.4.1
#   Downloading https://files.pythonhosted.org/packages/7b/b8/88def36e74bee9fce511c9519571f4e485e890093ab7442284f4ffaef60b/google_auth_oauthlib-0.4.1-py2.py3-none-any.whl
# Requirement already satisfied: google-pasta==0.2.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 11)) (0.2.0)
# Requirement already satisfied: grpcio==1.32.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 12)) (1.32.0)
# Requirement already satisfied: h5py==2.10.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 13)) (2.10.0)
# Requirement already satisfied: idna==2.10 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 14)) (2.10)
# Collecting imageio==2.9.0
#   Downloading https://files.pythonhosted.org/packages/6e/57/5d899fae74c1752f52869b613a8210a2480e1a69688e65df6cb26117d45d/imageio-2.9.0-py3-none-any.whl (3.3MB)
#      |████████████████████████████████| 3.3MB 12.5MB/s
# Collecting importlib-metadata==2.0.0
#   Downloading https://files.pythonhosted.org/packages/6d/6d/f4bb28424bc677bce1210bc19f69a43efe823e294325606ead595211f93e/importlib_metadata-2.0.0-py2.py3-none-any.whl
# Collecting Keras-Applications==1.0.8
#   Downloading https://files.pythonhosted.org/packages/71/e3/19762fdfc62877ae9102edf6342d71b28fbfd9dea3d2f96a882ce099b03f/Keras_Applications-1.0.8-py3-none-any.whl (50kB)
#      |████████████████████████████████| 51kB 8.2MB/s
# Requirement already satisfied: Keras-Preprocessing==1.1.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 18)) (1.1.2)
# Collecting kiwisolver==1.2.0
#   Downloading https://files.pythonhosted.org/packages/31/b9/6202dcae729998a0ade30e80ac00f616542ef445b088ec970d407dfd41c0/kiwisolver-1.2.0-cp37-cp37m-manylinux1_x86_64.whl (88kB)
#      |████████████████████████████████| 92kB 12.1MB/s
# Collecting Markdown==3.2.2
#   Downloading https://files.pythonhosted.org/packages/a4/63/eaec2bd025ab48c754b55e8819af0f6a69e2b1e187611dd40cbbe101ee7f/Markdown-3.2.2-py3-none-any.whl (88kB)
#      |████████████████████████████████| 92kB 12.2MB/s
# Collecting matplotlib==3.3.2
#   Downloading https://files.pythonhosted.org/packages/87/a6/8d7d06f6b69236a3c1818157875ceb1259ba0d9df4194f4fe138ffdc0f41/matplotlib-3.3.2-cp37-cp37m-manylinux1_x86_64.whl (11.6MB)
#      |████████████████████████████████| 11.6MB 218kB/s
# Collecting numpy==1.19.2
#   Downloading https://files.pythonhosted.org/packages/9b/04/c3846024ddc7514cde17087f62f0502abf85c53e8f69f6312c70db6d144e/numpy-1.19.2-cp37-cp37m-manylinux2010_x86_64.whl (14.5MB)
#      |████████████████████████████████| 14.5MB 242kB/s
# Requirement already satisfied: oauthlib==3.1.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 23)) (3.1.0)
# Collecting opencv-python==4.4.0.44
#   Downloading https://files.pythonhosted.org/packages/01/d0/23b56d1c4a301d57ffa5d9aa0df9894053e43e439c9a710c8986ad7b3999/opencv_python-4.4.0.44-cp37-cp37m-manylinux2014_x86_64.whl (49.5MB)
#      |████████████████████████████████| 49.5MB 66kB/s
# Requirement already satisfied: opt-einsum==3.3.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 25)) (3.3.0)
# Collecting Pillow==7.2.0
#   Downloading https://files.pythonhosted.org/packages/e8/f2/6722dd0c22e3a143ac792ccb2424924ac72af4adea756b1165b4cad50da7/Pillow-7.2.0-cp37-cp37m-manylinux1_x86_64.whl (2.2MB)
#      |████████████████████████████████| 2.2MB 51.8MB/s
# Collecting protobuf==3.13.0
#   Downloading https://files.pythonhosted.org/packages/71/dc/5ba56eab7440c62c5f808b4267e2a1d6c136e90293b43fefb1b493c6d704/protobuf-3.13.0-cp37-cp37m-manylinux1_x86_64.whl (1.3MB)
#      |████████████████████████████████| 1.3MB 49.5MB/s
# Requirement already satisfied: pyasn1==0.4.8 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 28)) (0.4.8)
# Requirement already satisfied: pyasn1-modules==0.2.8 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 29)) (0.2.8)
# Requirement already satisfied: pyparsing==2.4.7 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 30)) (2.4.7)
# Requirement already satisfied: python-dateutil==2.8.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 31)) (2.8.1)
# Collecting requests==2.24.0
#   Downloading https://files.pythonhosted.org/packages/45/1e/0c169c6a5381e241ba7404532c16a21d86ab872c9bed8bdcd4c423954103/requests-2.24.0-py2.py3-none-any.whl (61kB)
#      |████████████████████████████████| 71kB 10.8MB/s
# Requirement already satisfied: requests-oauthlib==1.3.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 33)) (1.3.0)
# Collecting rsa==4.6
#   Downloading https://files.pythonhosted.org/packages/1c/df/c3587a667d6b308fadc90b99e8bc8774788d033efcc70f4ecaae7fad144b/rsa-4.6-py3-none-any.whl (47kB)
#      |████████████████████████████████| 51kB 7.0MB/s
# Collecting scipy==1.5.2
#   Downloading https://files.pythonhosted.org/packages/65/f9/f7a7e5009711579c72da2725174825e5056741bf4001815d097eef1b2e17/scipy-1.5.2-cp37-cp37m-manylinux1_x86_64.whl (25.9MB)
#      |████████████████████████████████| 25.9MB 123kB/s
# Requirement already satisfied: six==1.15.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 36)) (1.15.0)
# Collecting tensorboard==2.0.2
#   Downloading https://files.pythonhosted.org/packages/76/54/99b9d5d52d5cb732f099baaaf7740403e83fe6b0cedde940fabd2b13d75a/tensorboard-2.0.2-py3-none-any.whl (3.8MB)
#      |████████████████████████████████| 3.8MB 55.2MB/s
# Collecting tensorflow==2.0.3
#   Downloading https://files.pythonhosted.org/packages/a1/c4/ba34ed5c06814944b57bc638c9501dea6be46407e0a7a846b6392fe23e2c/tensorflow-2.0.3-cp37-cp37m-manylinux2010_x86_64.whl (86.4MB)
#      |████████████████████████████████| 86.4MB 107kB/s
# Collecting tensorflow-estimator==2.0.1
#   Downloading https://files.pythonhosted.org/packages/fc/08/8b927337b7019c374719145d1dceba21a8bb909b93b1ad6f8fb7d22c1ca1/tensorflow_estimator-2.0.1-py2.py3-none-any.whl (449kB)
#      |████████████████████████████████| 450kB 50.9MB/s
# Requirement already satisfied: termcolor==1.1.0 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 40)) (1.1.0)
# Collecting urllib3==1.25.10
#   Downloading https://files.pythonhosted.org/packages/9f/f0/a391d1463ebb1b233795cabfc0ef38d3db4442339de68f847026199e69d7/urllib3-1.25.10-py2.py3-none-any.whl (127kB)
#      |████████████████████████████████| 133kB 60.9MB/s
# Requirement already satisfied: Werkzeug==1.0.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 42)) (1.0.1)
# Requirement already satisfied: wrapt==1.12.1 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 43)) (1.12.1)
# Collecting zipp==3.2.0
#   Downloading https://files.pythonhosted.org/packages/c4/79/3b770d51254a31bb85ba56ea70d7428d0c2c659a233cc9722352e028b539/zipp-3.2.0-py3-none-any.whl
# Requirement already satisfied: setuptools>=40.3.0 in /usr/local/lib/python3.7/dist-packages (from google-auth==1.21.3->-r requirements.txt (line 9)) (54.2.0)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.7/dist-packages (from tensorboard==2.0.2->-r requirements.txt (line 37)) (0.36.2)
# Building wheels for collected packages: gast
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.2.2-cp37-none-any.whl size=7540 sha256=00f66bfa5e99f1de6aaf76495328ab4a201b29a9070c1012d9bf30e13192522d
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# Successfully built gast
# ERROR: tensorflow 2.0.3 has requirement numpy<1.19.0,>=1.16.0, but you'll have numpy 1.19.2 which is incompatible.
# ERROR: tensorflow-probability 0.12.1 has requirement gast>=0.3.2, but you'll have gast 0.2.2 which is incompatible.
# ERROR: google-colab 1.0.0 has requirement requests~=2.23.0, but you'll have requests 2.24.0 which is incompatible.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: absl-py, cachetools, certifi, gast, rsa, google-auth, google-auth-oauthlib, Pillow, numpy, imageio, zipp, importlib-metadata, Keras-Applications, kiwisolver, Markdown, matplotlib, opencv-python, protobuf, urllib3, requests, scipy, tensorboard, tensorflow-estimator, tensorflow
#   Found existing installation: absl-py 0.12.0
#     Uninstalling absl-py-0.12.0:
#       Successfully uninstalled absl-py-0.12.0
#   Found existing installation: cachetools 4.2.1
#     Uninstalling cachetools-4.2.1:
#       Successfully uninstalled cachetools-4.2.1
#   Found existing installation: certifi 2020.12.5
#     Uninstalling certifi-2020.12.5:
#       Successfully uninstalled certifi-2020.12.5
#   Found existing installation: gast 0.3.3
#     Uninstalling gast-0.3.3:
#       Successfully uninstalled gast-0.3.3
#   Found existing installation: rsa 4.7.2
#     Uninstalling rsa-4.7.2:
#       Successfully uninstalled rsa-4.7.2
#   Found existing installation: google-auth 1.28.1
#     Uninstalling google-auth-1.28.1:
#       Successfully uninstalled google-auth-1.28.1
#   Found existing installation: google-auth-oauthlib 0.4.4
#     Uninstalling google-auth-oauthlib-0.4.4:
#       Successfully uninstalled google-auth-oauthlib-0.4.4
#   Found existing installation: Pillow 7.1.2
#     Uninstalling Pillow-7.1.2:
#       Successfully uninstalled Pillow-7.1.2
#   Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
#   Found existing installation: imageio 2.4.1
#     Uninstalling imageio-2.4.1:
#       Successfully uninstalled imageio-2.4.1
#   Found existing installation: zipp 3.4.1
#     Uninstalling zipp-3.4.1:
#       Successfully uninstalled zipp-3.4.1
#   Found existing installation: importlib-metadata 3.10.1
#     Uninstalling importlib-metadata-3.10.1:
#       Successfully uninstalled importlib-metadata-3.10.1
#   Found existing installation: kiwisolver 1.3.1
#     Uninstalling kiwisolver-1.3.1:
#       Successfully uninstalled kiwisolver-1.3.1
#   Found existing installation: Markdown 3.3.4
#     Uninstalling Markdown-3.3.4:
#       Successfully uninstalled Markdown-3.3.4
#   Found existing installation: matplotlib 3.2.2
#     Uninstalling matplotlib-3.2.2:
#       Successfully uninstalled matplotlib-3.2.2
#   Found existing installation: opencv-python 4.1.2.30
#     Uninstalling opencv-python-4.1.2.30:
#       Successfully uninstalled opencv-python-4.1.2.30
#   Found existing installation: protobuf 3.12.4
#     Uninstalling protobuf-3.12.4:
#       Successfully uninstalled protobuf-3.12.4
#   Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
#   Found existing installation: tensorboard 2.4.1
#     Uninstalling tensorboard-2.4.1:
#       Successfully uninstalled tensorboard-2.4.1
#   Found existing installation: tensorflow-estimator 2.4.0
#     Uninstalling tensorflow-estimator-2.4.0:
#       Successfully uninstalled tensorflow-estimator-2.4.0
#   Found existing installation: tensorflow 2.4.1
#     Uninstalling tensorflow-2.4.1:
#       Successfully uninstalled tensorflow-2.4.1
# Successfully installed Keras-Applications-1.0.8 Markdown-3.2.2 Pillow-7.2.0 absl-py-0.10.0 cachetools-4.1.1 certifi-2020.6.20 gast-0.2.2 google-auth-1.21.3 google-auth-oauthlib-0.4.1 imageio-2.9.0 importlib-metadata-2.0.0 kiwisolver-1.2.0 matplotlib-3.3.2 numpy-1.19.2 opencv-python-4.4.0.44 protobuf-3.13.0 requests-2.24.0 rsa-4.6 scipy-1.5.2 tensorboard-2.0.2 tensorflow-2.0.3 tensorflow-estimator-2.0.1 urllib3-1.25.10 zipp-3.2.0

# %% [markdown]
# ## 获取并处理data

# %%
! . fetch_data.sh
# Out:
# --2021-04-22 01:32:18--  http://cs-people.bu.edu/giorgos/puppetgan/data.tar.gz
# Resolving cs-people.bu.edu (cs-people.bu.edu)... 128.197.11.71
# Connecting to cs-people.bu.edu (cs-people.bu.edu)|128.197.11.71|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20165408 (19M) [application/x-gzip]
# Saving to: ‘STDOUT’
#
# -                   100%[===================>]  19.23M   218KB/s    in 3m 33s
#
# 2021-04-22 01:35:52 (92.4 KB/s) - written to stdout [20165408/20165408]

# %%
import os

# %%
% cd ../../synth_/synth
# Out:
# /content/drive/My Drive/BU_CS585/PuppetGAN/data/mnist/synth_/synth

# %%
! ls -a

# %%
filePath = './'

for filename in os.listdir(filePath):
    if filename.startswith('._'):
        print(filename)
        os.remove(filename)

# %%
! ls -a

# %% [markdown]
# ## Train a model

# %%
% cd ./drive/MyDrive/BU_CS585/PuppetGAN/PuppetGAN
# Out:
# /content/drive/MyDrive/BU_CS585/PuppetGAN/PuppetGAN

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
! pip install tensorflow-gpu

# %%
! python3 main.py
# Out:
# 2021-04-22 02:16:08.893022: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-04-22 02:16:10.921626: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-04-22 02:16:10.922698: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-04-22 02:16:10.928606: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-22 02:16:10.929183: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2021-04-22 02:16:10.929221: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-04-22 02:16:10.931884: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2021-04-22 02:16:10.931960: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2021-04-22 02:16:10.940645: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-04-22 02:16:10.941007: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-04-22 02:16:10.942846: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-04-22 02:16:10.943423: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2021-04-22 02:16:10.943616: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2021-04-22 02:16:10.943719: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-22 02:16:10.944316: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-22 02:16:10.944849: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-04-22 02:16:10.945134: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-04-22 02:16:10.945275: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-04-22 02:16:10.945392: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-22 02:16:10.945962: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2021-04-22 02:16:10.945995: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-04-22 02:16:10.946028: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2021-04-22 02:16:10.946050: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2021-04-22 02:16:10.946069: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-04-22 02:16:10.946087: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-04-22 02:16:10.946105: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-04-22 02:16:10.946123: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2021-04-22 02:16:10.946142: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2021-04-22 02:16:10.946206: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-22 02:16:10.946772: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-22 02:16:10.947285: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-04-22 02:16:10.947333: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-04-22 02:16:11.520222: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-04-22 02:16:11.520298: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2021-04-22 02:16:11.520316: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2021-04-22 02:16:11.520517: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-22 02:16:11.521305: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-22 02:16:11.521887: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-22 02:16:11.522390: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2021-04-22 02:16:11.522442: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 13735 MB memory) -> physical GPU (device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5)
#
# Epoch: 0 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# 2021-04-22 02:16:55.630838: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2021-04-22 02:16:56.004619: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2199995000 Hz
# 2021-04-22 02:17:05.679362: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2021-04-22 02:17:08.199671: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2021-04-22 02:17:08.260251: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
#
# 	Creating evaluation rows.
# 	Saved evaluation rows and gifs for epoch 0!
# 	Saved losses and images for epoch 0!
# 	Saved checkpoint for epoch 0 at ./checkpoints/puppetGAN/ckpt-1!
#
# 	Reconstruction Loss:	2.7064894288778305
# 	Disentanglement Loss:	0.6702033778031667
# 	Cycle Loss:		2.7189017136891684
# 	Attribute Cycle Loss:	2.831526497999827
#
# 	Real Generator Loss:	4.71341747045517
# 	Real Discriminator Loss:	2.897354672352473
#
# 	Synthetic Generator Loss:	5.497458000977834
# 	Synthetic Discriminator Loss:	2.9386350562175116
#
# 	Time taken for epoch 0: 254.2113893032074sec.
#
# Epoch: 1 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# 	Reconstruction Loss:	1.5318091015021007
# 	Disentanglement Loss:	0.37884218866626423
# 	Cycle Loss:		1.54860952993234
# 	Attribute Cycle Loss:	1.6455165197451909
#
# 	Real Generator Loss:	3.6706603169441223
# 	Real Discriminator Loss:	1.9404656092325847
#
# 	Synthetic Generator Loss:	4.014433006445567
# 	Synthetic Discriminator Loss:	2.2142345756292343
#
# 	Time taken for epoch 1: 120.62645411491394sec.
#
# Epoch: 2 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# 	Reconstruction Loss:	1.1324186970790227
# 	Disentanglement Loss:	0.2816675305366516
# 	Cycle Loss:		1.1575344105561574
# 	Attribute Cycle Loss:	1.2652669847011566
#
# 	Real Generator Loss:	4.94864347577095
# 	Real Discriminator Loss:	1.4549278020858765
#
# 	Synthetic Generator Loss:	6.276524235804875
# 	Synthetic Discriminator Loss:	1.2584607352813084
#
# 	Time taken for epoch 2: 120.96732234954834sec.
#
# Epoch: 3 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# 	Reconstruction Loss:	0.9171552881598473
# 	Disentanglement Loss:	0.23428803061445555
# 	Cycle Loss:		0.9508567278583845
# 	Attribute Cycle Loss:	1.0795495808124542
#
# 	Real Generator Loss:	4.188825200001399
# 	Real Discriminator Loss:	2.1243058294057846
#
# 	Synthetic Generator Loss:	4.500381886959076
# 	Synthetic Discriminator Loss:	2.3935824731985726
#
# 	Time taken for epoch 3: 120.89927744865417sec.
#
# Epoch: 4 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# 	Reconstruction Loss:	0.7219354882836342
# 	Disentanglement Loss:	0.19121892812351385
# 	Cycle Loss:		0.766952226559321
# 	Attribute Cycle Loss:	0.9031072904666265
#
# 	Real Generator Loss:	3.488062471151352
# 	Real Discriminator Loss:	2.7754367689291635
#
# 	Synthetic Generator Loss:	3.8958629171053567
# 	Synthetic Discriminator Loss:	3.2733046611150107
#
# 	Time taken for epoch 4: 120.92698287963867sec.
#
# Epoch: 5 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# 	Reconstruction Loss:	0.5835726261138916
# 	Disentanglement Loss:	0.16165125804642835
# 	Cycle Loss:		0.6297060549259186
# 	Attribute Cycle Loss:	0.7706930264830589
#
# 	Real Generator Loss:	3.0955851624409356
# 	Real Discriminator Loss:	3.15138711531957
#
# 	Synthetic Generator Loss:	3.2005042110880217
# 	Synthetic Discriminator Loss:	4.002991219361623
#
# 	Time taken for epoch 5: 121.02072525024414sec.
#
# Epoch: 6 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# 	Reconstruction Loss:	0.4805636977156003
# 	Disentanglement Loss:	0.14041814083854356
# 	Cycle Loss:		0.524327332774798
# 	Attribute Cycle Loss:	0.6685591836770376
#
# 	Real Generator Loss:	2.727147951722145
# 	Real Discriminator Loss:	3.534590800603231
#
# 	Synthetic Generator Loss:	2.982552339633306
# 	Synthetic Discriminator Loss:	3.9911473989486694
#
# 	Time taken for epoch 6: 120.9021508693695sec.
#
# Epoch: 7 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# 	Reconstruction Loss:	0.40879752362767857
# 	Disentanglement Loss:	0.12524983007460833
# 	Cycle Loss:		0.45343100776274997
# 	Attribute Cycle Loss:	0.5894357040524483
#
# 	Real Generator Loss:	2.6347489754358926
# 	Real Discriminator Loss:	3.92342800895373
#
# 	Synthetic Generator Loss:	2.8542571713527045
# 	Synthetic Discriminator Loss:	4.503568192323049
#
# 	Time taken for epoch 7: 120.9104790687561sec.
#
# Epoch: 8 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# 	Reconstruction Loss:	0.3498156666755676
# 	Disentanglement Loss:	0.1134976635997494
# 	Cycle Loss:		0.39062945917248726
# 	Attribute Cycle Loss:	0.5193432793021202
#
# 	Real Generator Loss:	2.499622275431951
# 	Real Discriminator Loss:	3.9729515810807547
#
# 	Synthetic Generator Loss:	2.709986294309298
# 	Synthetic Discriminator Loss:	4.7104573249816895
#
# 	Time taken for epoch 8: 120.8049738407135sec.
#
# Epoch: 9 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# 	Reconstruction Loss:	0.3100323900580406
# 	Disentanglement Loss:	0.1045054296652476
# 	Cycle Loss:		0.35167138651013374
# 	Attribute Cycle Loss:	0.471546517064174
#
# 	Real Generator Loss:	2.537763079007467
# 	Real Discriminator Loss:	4.094219744205475
#
# 	Synthetic Generator Loss:	2.5942211151123047
# 	Synthetic Discriminator Loss:	4.786325414975484
#
# 	Time taken for epoch 9: 120.7890694141388sec.
#
# Epoch: 10 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# 	Reconstruction Loss:	0.2752394328514735
# 	Disentanglement Loss:	0.09660304803401232
# 	Cycle Loss:		0.31350847085316974
# 	Attribute Cycle Loss:	0.43034398928284645
#
# 	Real Generator Loss:	2.429324413339297
# 	Real Discriminator Loss:	4.194413125514984
#
# 	Synthetic Generator Loss:	2.570140853524208
# 	Synthetic Discriminator Loss:	4.908958315849304
#
# 	Time taken for epoch 10: 121.4953191280365sec.
#
# Epoch: 11 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# 	Reconstruction Loss:	0.2518423789491256
# 	Disentanglement Loss:	0.09106353142609198
# 	Cycle Loss:		0.2879165473083655
# 	Attribute Cycle Loss:	0.40295655528704327
#
# 	Real Generator Loss:	2.4547948042551675
# 	Real Discriminator Loss:	4.3165998458862305
#
# 	Synthetic Generator Loss:	2.541422039270401
# 	Synthetic Discriminator Loss:	4.931407928466797
#
# 	Time taken for epoch 11: 120.84719395637512sec.
#
# Epoch: 12 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# 	Reconstruction Loss:	0.2330994059642156
# 	Disentanglement Loss:	0.08613045203189056
# 	Cycle Loss:		0.26852916926145554
# 	Attribute Cycle Loss:	0.37812890360752743
#
# 	Real Generator Loss:	2.377227013309797
# 	Real Discriminator Loss:	4.313547174135844
#
# 	Synthetic Generator Loss:	2.520267575979233
# 	Synthetic Discriminator Loss:	4.976543406645457
#
# 	Time taken for epoch 12: 120.83773875236511sec.
#
# Epoch: 13 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# 	Reconstruction Loss:	0.2207465060055256
# 	Disentanglement Loss:	0.08335011452436447
# 	Cycle Loss:		0.2572352352241675
# 	Attribute Cycle Loss:	0.36328670134147006
#
# 	Real Generator Loss:	2.3988673786322274
# 	Real Discriminator Loss:	4.362594465414683
#
# 	Synthetic Generator Loss:	2.532939851284027
# 	Synthetic Discriminator Loss:	4.990934610366821
#
# 	Time taken for epoch 13: 120.76006555557251sec.
#
# Epoch: 14 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# 	Reconstruction Loss:	0.20621469678978124
# 	Disentanglement Loss:	0.07977778371423483
# 	Cycle Loss:		0.2386989245812098
# 	Attribute Cycle Loss:	0.34455182030797005
#
# 	Real Generator Loss:	2.3649383236964545
# 	Real Discriminator Loss:	4.3866084814071655
#
# 	Synthetic Generator Loss:	2.5160746475060782
# 	Synthetic Discriminator Loss:	5.006985465685527
#
# 	Time taken for epoch 14: 120.92250418663025sec.
#
# Epoch: 15 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# 	Reconstruction Loss:	0.19673782462875047
# 	Disentanglement Loss:	0.07671296130865812
# 	Cycle Loss:		0.22883705360194048
# 	Attribute Cycle Loss:	0.334022185454766
#
# 	Real Generator Loss:	2.387349476416906
# 	Real Discriminator Loss:	4.3935308655103045
#
# 	Synthetic Generator Loss:	2.5125445425510406
# 	Synthetic Discriminator Loss:	5.009218513965607
#
# 	Time taken for epoch 15: 120.73814511299133sec.
#
# Epoch: 16 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# 	Reconstruction Loss:	0.18852154227594534
# 	Disentanglement Loss:	0.07446723338216543
# 	Cycle Loss:		0.21934014620880285
# 	Attribute Cycle Loss:	0.3223975636065006
#
# 	Real Generator Loss:	2.3735115279754004
# 	Real Discriminator Loss:	4.386546711126964
#
# 	Synthetic Generator Loss:	2.523915042479833
# 	Synthetic Discriminator Loss:	4.998307367165883
#
# 	Time taken for epoch 16: 121.02538132667542sec.
#
# Epoch: 17 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# 	Reconstruction Loss:	0.18421008065342903
# 	Disentanglement Loss:	0.07289411903669436
# 	Cycle Loss:		0.21760434346894422
# 	Attribute Cycle Loss:	0.31804849455753964
#
# 	Real Generator Loss:	2.3751234908898673
# 	Real Discriminator Loss:	4.408337255318959
#
# 	Synthetic Generator Loss:	2.5171965459982553
# 	Synthetic Discriminator Loss:	5.00341276327769
#
# 	Time taken for epoch 17: 120.84908175468445sec.
#
# Epoch: 18 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# 	Reconstruction Loss:	0.17489401747783026
# 	Disentanglement Loss:	0.07019856882592042
# 	Cycle Loss:		0.20466053299605846
# 	Attribute Cycle Loss:	0.3059336605171363
#
# 	Real Generator Loss:	2.36747312049071
# 	Real Discriminator Loss:	4.392102340857188
#
# 	Synthetic Generator Loss:	2.5171170930067697
# 	Synthetic Discriminator Loss:	4.998980661233266
#
# 	Time taken for epoch 18: 120.98051023483276sec.
#
# Epoch: 19 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# 	Reconstruction Loss:	0.17053082833687463
# 	Disentanglement Loss:	0.06885725446045399
# 	Cycle Loss:		0.20052377693355083
# 	Attribute Cycle Loss:	0.3017389973004659
#
# 	Real Generator Loss:	2.4012666443983712
# 	Real Discriminator Loss:	4.39028525352478
#
# 	Synthetic Generator Loss:	2.5330075919628143
# 	Synthetic Discriminator Loss:	4.997335334618886
#
# 	Time taken for epoch 19: 120.84275317192078sec.
#
# Epoch: 20 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# 	Reconstruction Loss:	0.16662215503553549
# 	Disentanglement Loss:	0.06760669468591611
# 	Cycle Loss:		0.19571014493703842
# 	Attribute Cycle Loss:	0.29459922512372333
#
# 	Real Generator Loss:	2.3805631498495736
# 	Real Discriminator Loss:	4.380831976731618
#
# 	Synthetic Generator Loss:	2.5378341178099313
# 	Synthetic Discriminator Loss:	5.001984099547069
#
# 	Time taken for epoch 20: 120.76747846603394sec.
#
# Epoch: 21 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# 	Reconstruction Loss:	0.16113970739146075
# 	Disentanglement Loss:	0.06574926556398471
# 	Cycle Loss:		0.18904319033026695
# 	Attribute Cycle Loss:	0.289947842558225
#
# 	Real Generator Loss:	2.3861325830221176
# 	Real Discriminator Loss:	4.402640561262767
#
# 	Synthetic Generator Loss:	2.5336930255095163
# 	Synthetic Discriminator Loss:	4.975422124067943
#
# 	Time taken for epoch 21: 120.90493392944336sec.
#
# Epoch: 22 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# 	Reconstruction Loss:	0.15728413003186384
# 	Disentanglement Loss:	0.06497444569443662
# 	Cycle Loss:		0.18486694494883218
# 	Attribute Cycle Loss:	0.28496138503154117
#
# 	Real Generator Loss:	2.3822192202011743
# 	Real Discriminator Loss:	4.396352450052897
#
# 	Synthetic Generator Loss:	2.5401056706905365
# 	Synthetic Discriminator Loss:	4.978301266829173
#
# 	Time taken for epoch 22: 120.96855759620667sec.
#
# Epoch: 23 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# 	Reconstruction Loss:	0.15466338396072388
# 	Disentanglement Loss:	0.0636394430572788
# 	Cycle Loss:		0.1834956326832374
# 	Attribute Cycle Loss:	0.28222520897785824
#
# 	Real Generator Loss:	2.3887237111727395
# 	Real Discriminator Loss:	4.379314045111339
#
# 	Synthetic Generator Loss:	2.5311028957366943
# 	Synthetic Discriminator Loss:	4.981948812802632
#
# 	Time taken for epoch 23: 120.92123937606812sec.
#
# Epoch: 24 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# 	Reconstruction Loss:	0.15287326959272227
# 	Disentanglement Loss:	0.06309595750644803
# 	Cycle Loss:		0.1809661046912273
# 	Attribute Cycle Loss:	0.27912809203068417
#
# 	Real Generator Loss:	2.3881937811772027
# 	Real Discriminator Loss:	4.38630223274231
#
# 	Synthetic Generator Loss:	2.538358340660731
# 	Synthetic Discriminator Loss:	4.975171804428101
#
# 	Time taken for epoch 24: 120.77567481994629sec.
#
# Epoch: 25 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# 	Reconstruction Loss:	0.14887357192734876
# 	Disentanglement Loss:	0.061934963800013065
# 	Cycle Loss:		0.17572691726187864
# 	Attribute Cycle Loss:	0.27449842418233555
#
# 	Real Generator Loss:	2.373596211274465
# 	Real Discriminator Loss:	4.395139197508494
#
# 	Synthetic Generator Loss:	2.529578228791555
# 	Synthetic Discriminator Loss:	4.976650834083557
#
# 	Time taken for epoch 25: 120.76504254341125sec.
#
# Epoch: 26 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# 	Reconstruction Loss:	0.14852050629754862
# 	Disentanglement Loss:	0.06130659952759743
# 	Cycle Loss:		0.1772342026233673
# 	Attribute Cycle Loss:	0.273768359174331
#
# 	Real Generator Loss:	2.3853790064652762
# 	Real Discriminator Loss:	4.392079492410024
#
# 	Synthetic Generator Loss:	2.5504386126995087
# 	Synthetic Discriminator Loss:	4.964619914690654
#
# 	Time taken for epoch 26: 120.74387574195862sec.
#
# Epoch: 27 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# 	Reconstruction Loss:	0.14446135610342026
# 	Disentanglement Loss:	0.06046416346604625
# 	Cycle Loss:		0.1725190474341313
# 	Attribute Cycle Loss:	0.2700364241997401
#
# 	Real Generator Loss:	2.3956034779548645
# 	Real Discriminator Loss:	4.391771833101909
#
# 	Synthetic Generator Loss:	2.555975536505381
# 	Synthetic Discriminator Loss:	4.974879125754039
#
# 	Time taken for epoch 27: 120.64169192314148sec.
#
# Epoch: 28 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# 	Reconstruction Loss:	0.14322791745265326
# 	Disentanglement Loss:	0.059796279296278954
# 	Cycle Loss:		0.16946339731415114
# 	Attribute Cycle Loss:	0.2656160245339076
#
# 	Real Generator Loss:	2.3605978190898895
# 	Real Discriminator Loss:	4.390722115834554
#
# 	Synthetic Generator Loss:	2.522790551185608
# 	Synthetic Discriminator Loss:	4.963187913099925
#
# 	Time taken for epoch 28: 121.2221519947052sec.
#
# Epoch: 29 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# 	Reconstruction Loss:	0.1405812365313371
# 	Disentanglement Loss:	0.058992399678876005
# 	Cycle Loss:		0.16624333212773004
# 	Attribute Cycle Loss:	0.26198441286881763
#
# 	Real Generator Loss:	2.388687695066134
# 	Real Discriminator Loss:	4.390303631623586
#
# 	Synthetic Generator Loss:	2.5512393017609916
# 	Synthetic Discriminator Loss:	4.9666606187820435
#
# 	Time taken for epoch 29: 120.6500632762909sec.
#
# Epoch: 30 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# 	Reconstruction Loss:	0.13675400676826635
# 	Disentanglement Loss:	0.058321170353641115
# 	Cycle Loss:		0.16189273819327354
# 	Attribute Cycle Loss:	0.2589053424696128
#
# 	Real Generator Loss:	2.3731021086374917
# 	Real Discriminator Loss:	4.380261083443959
#
# 	Synthetic Generator Loss:	2.547147363424301
# 	Synthetic Discriminator Loss:	4.9627646406491595
#
# 	Time taken for epoch 30: 120.61673545837402sec.
#
# Epoch: 31 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# 	Reconstruction Loss:	0.1365512361129125
# 	Disentanglement Loss:	0.05795910411203901
# 	Cycle Loss:		0.161905604104201
# 	Attribute Cycle Loss:	0.2577266450971365
#
# 	Real Generator Loss:	2.393625477949778
# 	Real Discriminator Loss:	4.4186806082725525
#
# 	Synthetic Generator Loss:	2.550749972462654
# 	Synthetic Discriminator Loss:	4.969882786273956
#
# 	Time taken for epoch 31: 120.66631364822388sec.
#
# Epoch: 32 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# 	Reconstruction Loss:	0.13353029390176138
# 	Disentanglement Loss:	0.05659661861136556
# 	Cycle Loss:		0.1583510022610426
# 	Attribute Cycle Loss:	0.2539812369892995
#
# 	Real Generator Loss:	2.3630463679631553
# 	Real Discriminator Loss:	4.373838444550832
#
# 	Synthetic Generator Loss:	2.5449297527472177
# 	Synthetic Discriminator Loss:	4.959612766901652
#
# 	Time taken for epoch 32: 120.59324598312378sec.
#
# Epoch: 33 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# 	Reconstruction Loss:	0.13319835842897496
# 	Disentanglement Loss:	0.05648713046684861
# 	Cycle Loss:		0.15858524044354758
# 	Attribute Cycle Loss:	0.2521211560815573
#
# 	Real Generator Loss:	2.389239286382993
# 	Real Discriminator Loss:	4.394457856814067
#
# 	Synthetic Generator Loss:	2.5420588850975037
# 	Synthetic Discriminator Loss:	4.948272665341695
#
# 	Time taken for epoch 33: 120.82490110397339sec.
#
# Epoch: 34 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# 	Reconstruction Loss:	0.13101250305771828
# 	Disentanglement Loss:	0.055363988814254604
# 	Cycle Loss:		0.15576203539967537
# 	Attribute Cycle Loss:	0.25005369385083515
#
# 	Real Generator Loss:	2.3681137015422187
# 	Real Discriminator Loss:	4.394527177015941
#
# 	Synthetic Generator Loss:	2.5643726736307144
# 	Synthetic Discriminator Loss:	4.96603528658549
#
# 	Time taken for epoch 34: 120.695796251297sec.
#
# Epoch: 35 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# 	Reconstruction Loss:	0.12990330097575983
# 	Disentanglement Loss:	0.054853664400676884
# 	Cycle Loss:		0.15412278100848198
# 	Attribute Cycle Loss:	0.24597529383997122
#
# 	Real Generator Loss:	2.3816164334615073
# 	Real Discriminator Loss:	4.3821859161059065
#
# 	Synthetic Generator Loss:	2.5539073646068573
# 	Synthetic Discriminator Loss:	4.962221046288808
#
# 	Time taken for epoch 35: 120.80082535743713sec.
#
# Epoch: 36 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# 	Reconstruction Loss:	0.12837037661423287
# 	Disentanglement Loss:	0.054546754652013384
# 	Cycle Loss:		0.15251736404995123
# 	Attribute Cycle Loss:	0.24501236279805502
#
# 	Real Generator Loss:	2.3689487675825753
# 	Real Discriminator Loss:	4.394433697064717
#
# 	Synthetic Generator Loss:	2.5484095017115274
# 	Synthetic Discriminator Loss:	4.951310416062673
#
# 	Time taken for epoch 36: 121.50553679466248sec.
#
# Epoch: 37 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# 	Reconstruction Loss:	0.12736624603470167
# 	Disentanglement Loss:	0.05457021715119481
# 	Cycle Loss:		0.15111364300052324
# 	Attribute Cycle Loss:	0.2426570188254118
#
# 	Real Generator Loss:	2.3711647391319275
# 	Real Discriminator Loss:	4.393997550010681
#
# 	Synthetic Generator Loss:	2.5477425158023834
# 	Synthetic Discriminator Loss:	4.952559530735016
#
# 	Time taken for epoch 37: 120.73123049736023sec.
#
# Epoch: 38 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# 	Reconstruction Loss:	0.1261959234252572
# 	Disentanglement Loss:	0.05373017846917113
# 	Cycle Loss:		0.15107386000454426
# 	Attribute Cycle Loss:	0.2411486922452847
#
# 	Real Generator Loss:	2.371527244647344
# 	Real Discriminator Loss:	4.376538177331288
#
# 	Synthetic Generator Loss:	2.554013262192408
# 	Synthetic Discriminator Loss:	4.962553838888804
#
# 	Time taken for epoch 38: 120.65097069740295sec.
#
# Epoch: 39 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# 	Reconstruction Loss:	0.1258912949512402
# 	Disentanglement Loss:	0.053230926704903446
# 	Cycle Loss:		0.15063627188404402
# 	Attribute Cycle Loss:	0.24022500092784563
#
# 	Real Generator Loss:	2.375609189271927
# 	Real Discriminator Loss:	4.406099379062653
#
# 	Synthetic Generator Loss:	2.5629541178544364
# 	Synthetic Discriminator Loss:	4.940767327944438
#
# 	Time taken for epoch 39: 120.78619503974915sec.
#
# Epoch: 40 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# 	Reconstruction Loss:	0.12426755173752706
# 	Disentanglement Loss:	0.05338942011197408
# 	Cycle Loss:		0.14757478050887585
# 	Attribute Cycle Loss:	0.23822863710423312
#
# 	Real Generator Loss:	2.384745940566063
# 	Real Discriminator Loss:	4.388970692952474
#
# 	Synthetic Generator Loss:	2.552026649316152
# 	Synthetic Discriminator Loss:	4.966753204663594
#
# 	Time taken for epoch 40: 120.75460600852966sec.
#
# Epoch: 41 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# 	Reconstruction Loss:	0.12082160916179419
# 	Disentanglement Loss:	0.05196385163192948
# 	Cycle Loss:		0.14269658736884594
# 	Attribute Cycle Loss:	0.23502884743114313
#
# 	Real Generator Loss:	2.363526557882627
# 	Real Discriminator Loss:	4.4155407547950745
#
# 	Synthetic Generator Loss:	2.5649562577406564
# 	Synthetic Discriminator Loss:	4.956851740678151
#
# 	Time taken for epoch 41: 120.93725800514221sec.
#
# Epoch: 42 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# 	Reconstruction Loss:	0.12155615010609229
# 	Disentanglement Loss:	0.05153915239498019
# 	Cycle Loss:		0.14480665512382984
# 	Attribute Cycle Loss:	0.23565448820590973
#
# 	Real Generator Loss:	2.3592589497566223
# 	Real Discriminator Loss:	4.380789220333099
#
# 	Synthetic Generator Loss:	2.5532826085885367
# 	Synthetic Discriminator Loss:	4.939637064933777
#
# 	Time taken for epoch 42: 120.70120644569397sec.
#
# Epoch: 43 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# 	Reconstruction Loss:	0.12031215522438288
# 	Disentanglement Loss:	0.051662223103145756
# 	Cycle Loss:		0.1440523819377025
# 	Attribute Cycle Loss:	0.23328614917894205
#
# 	Real Generator Loss:	2.3917295585076013
# 	Real Discriminator Loss:	4.420183698336284
#
# 	Synthetic Generator Loss:	2.543162390589714
# 	Synthetic Discriminator Loss:	4.9566840926806135
#
# 	Time taken for epoch 43: 120.72354769706726sec.
#
# Epoch: 44 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# 	Reconstruction Loss:	0.12013415278246005
# 	Disentanglement Loss:	0.05139135988429189
# 	Cycle Loss:		0.14463772562642893
# 	Attribute Cycle Loss:	0.2320683772365252
#
# 	Real Generator Loss:	2.3534087538719177
# 	Real Discriminator Loss:	4.375337203343709
#
# 	Synthetic Generator Loss:	2.5670957614978156
# 	Synthetic Discriminator Loss:	4.952382902304332
#
# 	Time taken for epoch 44: 120.7642936706543sec.
#
# Epoch: 45 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# 	Reconstruction Loss:	0.11772390113522609
# 	Disentanglement Loss:	0.05065875733271241
# 	Cycle Loss:		0.14006327899793783
# 	Attribute Cycle Loss:	0.22959931815663973
#
# 	Real Generator Loss:	2.359341303507487
# 	Real Discriminator Loss:	4.3790587186813354
#
# 	Synthetic Generator Loss:	2.5340045392513275
# 	Synthetic Discriminator Loss:	4.936930378278096
#
# 	Time taken for epoch 45: 121.09778237342834sec.
#
# Epoch: 46 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# 	Reconstruction Loss:	0.11834934540092945
# 	Disentanglement Loss:	0.05041220240915815
# 	Cycle Loss:		0.14170953196783861
# 	Attribute Cycle Loss:	0.22913945962985358
#
# 	Real Generator Loss:	2.3710412134726844
# 	Real Discriminator Loss:	4.405227025349935
#
# 	Synthetic Generator Loss:	2.584325780471166
# 	Synthetic Discriminator Loss:	4.958441138267517
#
# 	Time taken for epoch 46: 121.12450098991394sec.
#
# Epoch: 47 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# 	Reconstruction Loss:	0.11689969804137945
# 	Disentanglement Loss:	0.05059485727300247
# 	Cycle Loss:		0.1393949364622434
# 	Attribute Cycle Loss:	0.22824027948081493
#
# 	Real Generator Loss:	2.350046585003535
# 	Real Discriminator Loss:	4.391964336236318
#
# 	Synthetic Generator Loss:	2.5540635536114373
# 	Synthetic Discriminator Loss:	4.95026417573293
#
# 	Time taken for epoch 47: 120.81767177581787sec.
#
# Epoch: 48 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# 	Reconstruction Loss:	0.11472984682768583
# 	Disentanglement Loss:	0.049181186594069004
# 	Cycle Loss:		0.13684988828996816
# 	Attribute Cycle Loss:	0.22470537945628166
#
# 	Real Generator Loss:	2.380953753987948
# 	Real Discriminator Loss:	4.396944244702657
#
# 	Synthetic Generator Loss:	2.557065427303314
# 	Synthetic Discriminator Loss:	4.937825123469035
#
# 	Time taken for epoch 48: 120.77300882339478sec.
#
# Epoch: 49 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# 	Reconstruction Loss:	0.11355362553149462
# 	Disentanglement Loss:	0.04910851207872232
# 	Cycle Loss:		0.13595970471700033
# 	Attribute Cycle Loss:	0.22259151252607504
#
# 	Real Generator Loss:	2.349828670422236
# 	Real Discriminator Loss:	4.378635863463084
#
# 	Synthetic Generator Loss:	2.5818448712428412
# 	Synthetic Discriminator Loss:	4.95777960618337
#
# 	Time taken for epoch 49: 120.75229501724243sec.
#
# Epoch: 50 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
#
# 	Creating evaluation rows.
# 	Saved evaluation rows and gifs for epoch 50!
# 	Saved losses and images for epoch 50!
# 	Saved checkpoint for epoch 50 at ./checkpoints/puppetGAN/ckpt-2!
#
# 	Reconstruction Loss:	0.1137511096894741
# 	Disentanglement Loss:	0.048674718321611486
# 	Cycle Loss:		0.136687150845925
# 	Attribute Cycle Loss:	0.22226040127376714
#
# 	Real Generator Loss:	2.383003607392311
# 	Real Discriminator Loss:	4.4151814977327986
#
# 	Synthetic Generator Loss:	2.5483012596766152
# 	Synthetic Discriminator Loss:	4.928651471932729
#
# 	Time taken for epoch 50: 176.57138013839722sec.
#
# Epoch: 51 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# 	Reconstruction Loss:	0.11273816817750533
# 	Disentanglement Loss:	0.04843517315263549
# 	Cycle Loss:		0.1345365463445584
# 	Attribute Cycle Loss:	0.22060146555304527
#
# 	Real Generator Loss:	2.3567558924357095
# 	Real Discriminator Loss:	4.3782545526822405
#
# 	Synthetic Generator Loss:	2.571457475423813
# 	Synthetic Discriminator Loss:	4.941456615924835
#
# 	Time taken for epoch 51: 121.1113555431366sec.
#
# Epoch: 52 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# 	Reconstruction Loss:	0.11273721605539322
# 	Disentanglement Loss:	0.04838163840274016
# 	Cycle Loss:		0.13527361676096916
# 	Attribute Cycle Loss:	0.22163973127802214
#
# 	Real Generator Loss:	2.370275696118673
# 	Real Discriminator Loss:	4.420846084753673
#
# 	Synthetic Generator Loss:	2.5683300495147705
# 	Synthetic Discriminator Loss:	4.95266330242157
#
# 	Time taken for epoch 52: 120.65697455406189sec.
#
# Epoch: 53 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# 	Reconstruction Loss:	0.1105979410931468
# 	Disentanglement Loss:	0.047709302666286625
# 	Cycle Loss:		0.13188476798435053
# 	Attribute Cycle Loss:	0.21761622776587805
#
# 	Real Generator Loss:	2.3530623515446982
# 	Real Discriminator Loss:	4.388926923274994
#
# 	Synthetic Generator Loss:	2.566104551156362
# 	Synthetic Discriminator Loss:	4.919814606507619
#
# 	Time taken for epoch 53: 121.06682133674622sec.
#
# Epoch: 54 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# 	Reconstruction Loss:	0.11029020293305318
# 	Disentanglement Loss:	0.047572255289802946
# 	Cycle Loss:		0.13232416721681753
# 	Attribute Cycle Loss:	0.2167643823971351
#
# 	Real Generator Loss:	2.3737075676520667
# 	Real Discriminator Loss:	4.407260358333588
#
# 	Synthetic Generator Loss:	2.5569021155436835
# 	Synthetic Discriminator Loss:	4.947362065315247
#
# 	Time taken for epoch 54: 120.85094594955444sec.
#
# Epoch: 55 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# 	Reconstruction Loss:	0.11095646116882563
# 	Disentanglement Loss:	0.04753832953671614
# 	Cycle Loss:		0.13378361922999224
# 	Attribute Cycle Loss:	0.21700014484425387
#
# 	Real Generator Loss:	2.356153726577759
# 	Real Discriminator Loss:	4.380097270011902
#
# 	Synthetic Generator Loss:	2.564880356192589
# 	Synthetic Discriminator Loss:	4.936104873816173
#
# 	Time taken for epoch 55: 120.74950504302979sec.
#
# Epoch: 56 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# 	Reconstruction Loss:	0.10949131504942973
# 	Disentanglement Loss:	0.046761971743156515
# 	Cycle Loss:		0.13090907409787178
# 	Attribute Cycle Loss:	0.21499699664612612
#
# 	Real Generator Loss:	2.360287735859553
# 	Real Discriminator Loss:	4.397722939650218
#
# 	Synthetic Generator Loss:	2.5669952630996704
# 	Synthetic Discriminator Loss:	4.934643944104512
#
# 	Time taken for epoch 56: 120.8187952041626sec.
#
# Epoch: 57 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# 	Reconstruction Loss:	0.10853556326280038
# 	Disentanglement Loss:	0.04673627996817231
# 	Cycle Loss:		0.12951027415692806
# 	Attribute Cycle Loss:	0.2136903094748656
#
# 	Real Generator Loss:	2.3725373645623526
# 	Real Discriminator Loss:	4.411869963010152
#
# 	Synthetic Generator Loss:	2.572396472096443
# 	Synthetic Discriminator Loss:	4.937911729017894
#
# 	Time taken for epoch 57: 120.8421905040741sec.
#
# Epoch: 58 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
# 	Reconstruction Loss:	0.10790858635058005
# 	Disentanglement Loss:	0.04615387615437309
# 	Cycle Loss:		0.1291215354576707
# 	Attribute Cycle Loss:	0.21277529808382192
#
# 	Real Generator Loss:	2.3506517906983695
# 	Real Discriminator Loss:	4.379069030284882
#
# 	Synthetic Generator Loss:	2.5757825821638107
# 	Synthetic Discriminator Loss:	4.939603726069133
#
# 	Time taken for epoch 58: 120.8708872795105sec.
#
# Epoch: 59 / 301
# Found 5000 images belonging to 1 classes.
# Found 5000 images belonging to 1 classes.
