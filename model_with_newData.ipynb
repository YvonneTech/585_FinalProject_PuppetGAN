# %%
% cd ./drive/MyDrive/BU_CS585/PuppetGAN/PuppetGAN
# Out:
# /content/drive/MyDrive/BU_CS585/PuppetGAN/PuppetGAN

# %%
! python3 main.py
# Out:
# 2021-04-23 09:32:38.156568: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-04-23 09:32:45.902226: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-04-23 09:32:45.911528: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-04-23 09:32:45.967447: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-04-23 09:32:45.968067: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# ...

# %%
% cd ..
# Out:
# /content/drive/My Drive/BU_CS585/PuppetGAN

# %%
import os

# %%
count = 0
path = './data/bodies/synth_/synth'

for filename in os.listdir(path):
    print(filename)
    count += 1

print(count)
# Out:
# 串流輸出內容已截斷至最後 5000 行。
# 0882.png
# 0885.png
# 0874.png
# 0875.png
# 0883.png
# 0876.png
# 0881.png
# 0878.png
# 0887.png
# 0886.png
# 0880.png
# 0877.png
# 0879.png
# 0888.png
# 0811.png
# 0802.png
# 0799.png
# 0810.png
# 0804.png
# 0800.png
# 0801.png
# 0809.png
# 0812.png
# 0807.png
# 0813.png
# 0808.png
# 0805.png
# 0806.png
# 0803.png
# 0838.png
# 0832.png
# 0842.png
# 0841.png
# 0839.png
# 0831.png
# 0834.png
# 0830.png
# 0840.png
# 0835.png
# 0836.png
# 0833.png
# 0829.png
# 0837.png
# 0843.png
# 0722.png
# 0715.png
# 0721.png
# 0720.png
# 0717.png
# 0723.png
# 0716.png
# 0709.png
# 0714.png
# 0712.png
# 0711.png
# 0719.png
# 0713.png
# 0710.png
# 0718.png
# 0764.png
# 0757.png
# 0761.png
# 0766.png
# 0759.png
# 0756.png
# 0754.png
# 0762.png
# 0765.png
# 0767.png
# 0755.png
# 0763.png
# 0760.png
# 0768.png
# 0758.png
# 0708.png
# 0706.png
# 0701.png
# 0698.png
# 0699.png
# 0707.png
# 0696.png
# 0695.png
# 0700.png
# 0697.png
# 0705.png
# 0694.png
# 0703.png
# 0704.png
# ...
